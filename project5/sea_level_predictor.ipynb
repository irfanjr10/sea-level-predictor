# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress 
import numpy as np

df = pd.read_csv('epa-sea-level.csv')
df.head()

plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])
plt.xlabel('year')
plt.ylabel('sea level(inches)')
plt.title('rise in sea level')

slope, intercept, r_value, p_value,std_err = linregress(df['Year'],df['CSIRO Adjusted Sea Level'])
years_extended = np.arange(1880,2051)
sea_level_pred = slope * years_extended + intercept
plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])
plt.plot(years_extended,sea_level_pred,'r',label='Best fit line(1880-2014)')

plt.xlabel('years')
plt.ylabel('sea level (inches)')
plt.title('rise in sea level')
plt.legend()
plt.show()

df_recent = df[df['Year'] >= 2000]
slope_recent ,intercept_recent ,r_value_recent , p_value_recent,std_err_recent = linregress(df_recent['year'],df_recent['CSIRO Adjusted Sea Level'])

years_recent = np.arrange(2000,2050)
sea_level_recent_pred = intercept_recent+slope_recent*years_recent

plt.plot(years_recent,sea_level_recent_pred,'g',label='best fit line(2000-2014)')
